# %% [markdown]
# <a href="https://colab.research.google.com/github/jdebnath21/Git-Commands/blob/master/Data_Visualization_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the libraries
import pandas as pd
import numpy as np

# %%
#read the dataset and check the first five rows
inp0 = pd.read_csv('googleplaystore_v2.csv')
inp0.head()
# Out:
#                                                  App  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
#Check the shape of the dataframe
inp0.shape
# Out:
# (10841, 13)
